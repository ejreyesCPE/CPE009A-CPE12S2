# %% [markdown]
# <a href="https://colab.research.google.com/github/ejreyesCPE/CPE009A-CPE12S2/blob/main/Midterm_Exam_in_OOP_(Question_23).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 23

# %%
for i in range(1, 6, 1):
  print("*"*i)
  i + 1

for i in range(4, 0,-1):
  print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
